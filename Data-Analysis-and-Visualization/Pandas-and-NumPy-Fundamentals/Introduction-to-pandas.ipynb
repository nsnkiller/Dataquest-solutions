# %% [markdown]
# ## Understanding pandas and NumPy

# %% [markdown]
# The primary data structure in pandas is called a dataframe. Dataframes are the pandas equivalent of a Numpy 2D ndarray, with a few key differences:
#
# * Axis values can have string **labels**, not just numeric ones.
# * Dataframes can contain columns with **multiple data types**: including integer, float, and string.

# %% [markdown]
# ![Jupyter](./df_anatomy_static_resized.svg)

# %% [markdown]
# ## Introduction to the Data

# %%
import pandas as pd

# %%
f500 = pd.read_csv('f500.csv',index_col=0)
f500_type = type(f500)
f500_shape = f500.shape

# %%
f500
# Out:
#                                 rank  revenues  revenue_change  profits  \
# company
# Walmart                            1    485873             0.8  13643.0
# State Grid                         2    315199            -4.4   9571.3
# Sinopec Group                      3    267518            -9.1   1257.9
# China National Petroleum           4    262573           -12.3   1867.5
# Toyota Motor                       5    254694             7.7  16899.3
# ...                              ...       ...             ...      ...
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
# AutoNation                       500     21609             3.6    430.5
#
#                                 assets  profit_change                  ceo  \
# company
# Walmart                         198825           -7.2  C. Douglas McMillon
# State Grid                      489838           -6.2              Kou Wei
# Sinopec Group                   310726          -65.0            Wang Yupu
# China National Petroleum        585619          -73.7        Zhang Jianhua
# Toyota Motor                    437575          -12.3          Akio Toyoda
# ...                                ...            ...                  ...
# Teva Pharmaceutical Industries   92890          -79.3    Yitzhak Peterburg
# New China Life Insurance        100609          -45.6             Wan Feng
# Wm. Morrison Supermarkets        11630           20.4       David T. Potts
# TUI                              16247          195.5    Friedrich Joussen
# AutoNation                       10060           -2.7   Michael J. Jackson
#
#                                                        industry  \
# company
# Walmart                                   General Merchandisers
# State Grid                                            Utilities
# Sinopec Group                                Petroleum Refining
# China National Petroleum                     Petroleum Refining
# Toyota Motor                           Motor Vehicles and Parts
# ...                                                         ...
# Teva Pharmaceutical Industries                  Pharmaceuticals
# New China Life Insurance        Insurance: Life, Health (stock)
# Wm. Morrison Supermarkets                  Food and Drug Stores
# TUI                                             Travel Services
# AutoNation                                  Specialty Retailers
#
#                                                 sector  previous_rank  \
# company
# Walmart                                      Retailing              1
# State Grid                                      Energy              2
# Sinopec Group                                   Energy              4
# China National Petroleum                        Energy              3
# Toyota Motor                    Motor Vehicles & Parts              8
# ...                                                ...            ...
# Teva Pharmaceutical Industries             Health Care              0
# New China Life Insurance                    Financials            427
# Wm. Morrison Supermarkets           Food & Drug Stores            437
# TUI                                  Business Services            467
# AutoNation                                   Retailing              0
#
#                                 country           hq_location  \
# company
# Walmart                             USA       Bentonville, AR
# State Grid                        China        Beijing, China
# Sinopec Group                     China        Beijing, China
# China National Petroleum          China        Beijing, China
# Toyota Motor                      Japan         Toyota, Japan
# ...                                 ...                   ...
# Teva Pharmaceutical Industries   Israel  Petach Tikva, Israel
# New China Life Insurance          China        Beijing, China
# Wm. Morrison Supermarkets       Britain     Bradford, Britain
# TUI                             Germany      Hanover, Germany
# AutoNation                          USA   Fort Lauderdale, FL
#
#                                                      website  \
# company
# Walmart                               http://www.walmart.com
# State Grid                            http://www.sgcc.com.cn
# Sinopec Group                         http://www.sinopec.com
# China National Petroleum              http://www.cnpc.com.cn
# Toyota Motor                    http://www.toyota-global.com
# ...                                                      ...
# Teva Pharmaceutical Industries      http://www.tevapharm.com
# New China Life Insurance         http://www.newchinalife.com
# Wm. Morrison Supermarkets           http://www.morrisons.com
# TUI                                  http://www.tuigroup.com
# AutoNation                         http://www.autonation.com
#
#                                 years_on_global_500_list  employees  \
# company
# Walmart                                               23    2300000
# State Grid                                            17     926067
# Sinopec Group                                         19     713288
# China National Petroleum                              17    1512048
# Toyota Motor                                          23     364445
# ...                                                  ...        ...
# Teva Pharmaceutical Industries                         1      56960
# New China Life Insurance                               2      54378
# Wm. Morrison Supermarkets                             13      77210
# TUI                                                   23      66779
# AutoNation                                            12      26000
#
#                                 total_stockholder_equity
# company
# Walmart                                            77798
# State Grid                                        209456
# Sinopec Group                                     106523
# China National Petroleum                          301893
# Toyota Motor                                      157210
# ...                                                  ...
# Teva Pharmaceutical Industries                     33337
# New China Life Insurance                            8507
# Wm. Morrison Supermarkets                           5111
# TUI                                                 3006
# AutoNation                                          2310
#
# [500 rows x 16 columns]

# %% [markdown]
# ## Introducing DataFrames

# %%
f500_head = f500.head(6)

# %%
f500_tail = f500.tail(8)

# %% [markdown]
# ## Introducing DataFrames Continued

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int64
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             500 non-null    int64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
#  13  years_on_global_500_list  500 non-null    int64
#  14  employees                 500 non-null    int64
#  15  total_stockholder_equity  500 non-null    int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 66.4+ KB

# %%
f500['industry'].value_counts()
# Out:
# Banks: Commercial and Savings                     51
# Motor Vehicles and Parts                          34
# Petroleum Refining                                28
# Insurance: Life, Health (stock)                   24
# Food and Drug Stores                              20
# Telecommunications                                18
# Mining, Crude-Oil Production                      18
# Insurance: Property and Casualty (Stock)          18
# Utilities                                         18
# Pharmaceuticals                                   15
# Trading                                           15
# Aerospace and Defense                             14
# Electronics, Electrical Equip.                    13
# Engineering, Construction                         13
# Energy                                            12
# Metals                                            12
# Industrial Machinery                              10
# Specialty Retailers                               10
# Insurance: Life, Health (Mutual)                   9
# Computers, Office Equipment                        8
# Diversified Financials                             8
# Airlines                                           8
# Food Production                                    7
# General Merchandisers                              7
# Chemicals                                          7
# Health Care: Insurance and Managed Care            6
# Internet Services and Retailing                    6
# Mail, Package, and Freight Delivery                6
# Real estate                                        6
# Wholesalers: Health Care                           6
# Food Consumer Products                             5
# Information Technology Services                    5
# Semiconductors and Other Electronic Components     5
# Network and Other Communications Equipment         4
# Building Materials, Glass                          4
# Wholesalers: Electronics and Office Equipment      3
# Beverages                                          3
# Entertainment                                      3
# Computer Software                                  3
# Pipelines                                          3
# Household and Personal Products                    3
# Railroads                                          3
# Wholesalers: Food and Grocery                      3
# Food Services                                      3
# Shipping                                           2
# Medical Products and Equipment                     2
# Apparel                                            2
# Temporary Help                                     2
# Health Care: Pharmacy and Other Services           2
# Health Care: Medical Facilities                    2
# Textiles                                           2
# Insurance: Property and Casualty (Mutual)          2
# Construction and Farm Machinery                    2
# Tobacco                                            1
# Wholesalers: Diversified                           1
# Miscellaneous                                      1
# Oil & Gas Equipment Services                       1
# Travel Services                                    1
# Name: industry, dtype: int64

# %%
f500['sector'].value_counts()
# Out:
# Financials                       118
# Energy                            80
# Technology                        44
# Motor Vehicles & Parts            34
# Wholesalers                       28
# Health Care                       27
# Food & Drug Stores                20
# Transportation                    19
# Telecommunications                18
# Retailing                         17
# Materials                         16
# Food, Beverages & Tobacco         16
# Industrials                       15
# Aerospace & Defense               14
# Engineering & Construction        13
# Chemicals                          7
# Household Products                 3
# Media                              3
# Business Services                  3
# Hotels, Restaurants & Leisure      3
# Apparel                            2
# Name: sector, dtype: int64

# %%
f500.groupby(['industry', 'sector']).size().sort_values(ascending=False)
# Out:
# industry                                        sector
# Banks: Commercial and Savings                   Financials                       51
# Motor Vehicles and Parts                        Motor Vehicles & Parts           34
# Petroleum Refining                              Energy                           28
# Insurance: Life, Health (stock)                 Financials                       24
# Food and Drug Stores                            Food & Drug Stores               20
# Insurance: Property and Casualty (Stock)        Financials                       18
# Utilities                                       Energy                           18
# Mining, Crude-Oil Production                    Energy                           18
# Telecommunications                              Telecommunications               18
# Trading                                         Wholesalers                      15
# Pharmaceuticals                                 Health Care                      15
# Aerospace and Defense                           Aerospace & Defense              14
# Electronics, Electrical Equip.                  Technology                       13
# Engineering, Construction                       Engineering & Construction       13
# Energy                                          Energy                           12
# Metals                                          Materials                        12
# Specialty Retailers                             Retailing                        10
# Industrial Machinery                            Industrials                      10
# Insurance: Life, Health (Mutual)                Financials                        9
# Diversified Financials                          Financials                        8
# Computers, Office Equipment                     Technology                        8
# Airlines                                        Transportation                    8
# Food Production                                 Food, Beverages & Tobacco         7
# General Merchandisers                           Retailing                         7
# Chemicals                                       Chemicals                         7
# Internet Services and Retailing                 Technology                        6
# Health Care: Insurance and Managed Care         Health Care                       6
# Wholesalers: Health Care                        Wholesalers                       6
# Mail, Package, and Freight Delivery             Transportation                    6
# Real estate                                     Financials                        6
# Information Technology Services                 Technology                        5
# Semiconductors and Other Electronic Components  Technology                        5
# Food Consumer Products                          Food, Beverages & Tobacco         5
# Network and Other Communications Equipment      Technology                        4
# Building Materials, Glass                       Materials                         4
# Food Services                                   Hotels, Restaurants & Leisure     3
# Wholesalers: Electronics and Office Equipment   Wholesalers                       3
# Beverages                                       Food, Beverages & Tobacco         3
# Computer Software                               Technology                        3
# Wholesalers: Food and Grocery                   Wholesalers                       3
# Entertainment                                   Media                             3
# Railroads                                       Transportation                    3
# Household and Personal Products                 Household Products                3
# Pipelines                                       Energy                            3
# Construction and Farm Machinery                 Industrials                       2
# Medical Products and Equipment                  Health Care                       2
# Apparel                                         Apparel                           2
# Health Care: Pharmacy and Other Services        Health Care                       2
# Insurance: Property and Casualty (Mutual)       Financials                        2
# Textiles                                        Industrials                       2
# Temporary Help                                  Business Services                 2
# Shipping                                        Transportation                    2
# Health Care: Medical Facilities                 Health Care                       2
# Travel Services                                 Business Services                 1
# Miscellaneous                                   Industrials                       1
# Wholesalers: Diversified                        Wholesalers                       1
# Oil & Gas Equipment Services                    Energy                            1
# Tobacco                                         Food, Beverages & Tobacco         1
# dtype: int64

# %%
f500.groupby('country')['revenues'].sum().sort_values(ascending=False)/sum(f500['revenues'])*100
# Out:
# country
# USA             30.593223
# China           21.792731
# Japan            9.785436
# Germany          6.689487
# France           5.780683
# Britain          4.468460
# Netherlands      3.117942
# South Korea      2.691927
# Switzerland      2.594721
# Spain            1.318766
# Brazil           1.314312
# Italy            1.311154
# Canada           1.264349
# India            1.010355
# Taiwan           1.003992
# Russia           0.941928
# Australia        0.851088
# Singapore        0.589584
# Ireland          0.473788
# Mexico           0.396904
# Sweden           0.302766
# Luxembourg       0.204961
# Malaysia         0.178572
# Thailand         0.175829
# Belgium          0.165673
# Norway           0.165558
# Indonesia        0.131683
# Denmark          0.127991
# Saudi Arabia     0.127836
# Finland          0.094243
# Venezuela        0.088071
# Turkey           0.084654
# U.A.E            0.082283
# Israel           0.079049
# Name: revenues, dtype: float64

# %% [markdown]
# ## Selecting a Column From a DataFrame by Label

# %%
industries = f500['industry']

# %%
industries_type = type(industries)

# %% [markdown]
# ## Selecting Columns From a DataFrame by Label Continued

# %%
countries = f500['country']
revenues_years = f500[['revenues', 'years_on_global_500_list']]
ceo_to_sector = f500.loc[:, 'ceo':'sector']

# %% [markdown]
# ## Selecting Rows From a DataFrame by Label

# %%
toyota = f500.loc['Toyota Motor']
toyota
# Out:
# rank                                                   5
# revenues                                          254694
# revenue_change                                       7.7
# profits                                          16899.3
# assets                                            437575
# profit_change                                      -12.3
# ceo                                          Akio Toyoda
# industry                        Motor Vehicles and Parts
# sector                            Motor Vehicles & Parts
# previous_rank                                          8
# country                                            Japan
# hq_location                                Toyota, Japan
# website                     http://www.toyota-global.com
# years_on_global_500_list                              23
# employees                                         364445
# total_stockholder_equity                          157210
# Name: Toyota Motor, dtype: object

# %%
drink_companies = f500.loc[['Anheuser-Busch InBev', 'Coca-Cola', 'Heineken Holding'], :]
drink_companies
# Out:
#                       rank  revenues  revenue_change  profits  assets  \
# company
# Anheuser-Busch InBev   206     45905             5.3   1241.0  258381
# Coca-Cola              235     41863            -5.5   6527.0   87270
# Heineken Holding       468     23044            -0.7    861.5   41469
#
#                       profit_change                        ceo   industry  \
# company
# Anheuser-Busch InBev          -85.0               Carlos Brito  Beverages
# Coca-Cola                     -11.2           James B. Quincey  Beverages
# Heineken Holding              -18.9  Jean-Francois van Boxmeer  Beverages
#
#                                          sector  previous_rank      country  \
# company
# Anheuser-Busch InBev  Food, Beverages & Tobacco            211      Belgium
# Coca-Cola             Food, Beverages & Tobacco            206          USA
# Heineken Holding      Food, Beverages & Tobacco            459  Netherlands
#
#                                  hq_location  \
# company
# Anheuser-Busch InBev         Leuven, Belgium
# Coca-Cola                        Atlanta, GA
# Heineken Holding      Amsterdam, Netherlands
#
#                                                 website  \
# company
# Anheuser-Busch InBev            http://www.ab-inbev.com
# Coca-Cola               http://www.coca-colacompany.com
# Heineken Holding      http://www.theheinekencompany.com
#
#                       years_on_global_500_list  employees  \
# company
# Anheuser-Busch InBev                        12     206633
# Coca-Cola                                   23     100300
# Heineken Holding                            11      73525
#
#                       total_stockholder_equity
# company
# Anheuser-Busch InBev                     71339
# Coca-Cola                                23062
# Heineken Holding                          6958

# %%
middle_companies = f500.loc['Tata Motors' :'Nationwide', 'rank': 'country']
middle_companies
# Out:
#                                  rank  revenues  revenue_change  profits  \
# company
# Tata Motors                       247     40329            -4.2   1111.6
# Aluminum Corp. of China           248     40278             6.0   -282.5
# Mitsui                            249     40275             1.6   2825.3
# Manulife Financial                250     40238            49.4   2209.7
# China Minsheng Banking            251     40234            -5.2   7201.6
# China Pacific Insurance (Group)   252     40193             2.2   1814.9
# American Airlines Group           253     40180            -2.0   2676.0
# Nationwide                        254     40074            -0.4    334.3
#
#                                  assets  profit_change                   ceo  \
# company
# Tata Motors                       42162          -34.0      Guenter Butschek
# Aluminum Corp. of China           75089            NaN              Yu Dehui
# Mitsui                           103231            NaN       Tatsuo Yasunaga
# Manulife Financial               537461           28.9     Donald A. Guloien
# China Minsheng Banking           848389           -1.8         Zheng Wanchun
# China Pacific Insurance (Group)  146873          -35.7          Huo Lianhong
# American Airlines Group           51274          -64.8     W. Douglas Parker
# Nationwide                       197790          -42.4  Stephen S. Rasmussen
#
#                                                                   industry  \
# company
# Tata Motors                                       Motor Vehicles and Parts
# Aluminum Corp. of China                                             Metals
# Mitsui                                                             Trading
# Manulife Financial                         Insurance: Life, Health (stock)
# China Minsheng Banking                       Banks: Commercial and Savings
# China Pacific Insurance (Group)            Insurance: Life, Health (stock)
# American Airlines Group                                           Airlines
# Nationwide                       Insurance: Property and Casualty (Mutual)
#
#                                                  sector  previous_rank country
# company
# Tata Motors                      Motor Vehicles & Parts            226   India
# Aluminum Corp. of China                       Materials            262   China
# Mitsui                                      Wholesalers            245   Japan
# Manulife Financial                           Financials            394  Canada
# China Minsheng Banking                       Financials            221   China
# China Pacific Insurance (Group)              Financials            251   China
# American Airlines Group                  Transportation            236     USA
# Nationwide                                   Financials            241     USA

# %% [markdown]
# ## Series vs Dataframes

# %% [markdown]
# ![Juyter](./df_series_s_updated.svg)
# ![Juyter](./df_series_df_updated.svg)

# %% [markdown]
# ## Value Counts Method

# %%
countries = f500['country']
country_counts = countries.value_counts()
country_counts
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Ireland           4
# Russia            4
# Sweden            3
# Singapore         3
# Mexico            2
# Finland           1
# Malaysia          1
# Venezuela         1
# U.A.E             1
# Norway            1
# Turkey            1
# Belgium           1
# Israel            1
# Denmark           1
# Thailand          1
# Saudi Arabia      1
# Indonesia         1
# Luxembourg        1
# Name: country, dtype: int64

# %% [markdown]
# ## Selecting Items from a Series by Label

# %%
countries = f500['country']
countries_counts = countries.value_counts()

# %%
india = countries_counts['India']
india
# Out:
# 7

# %%
north_america = countries_counts[['USA', 'Canada', 'Mexico']]
north_america
# Out:
# USA       132
# Canada     11
# Mexico      2
# Name: country, dtype: int64

# %% [markdown]
# ## Summary Challenge

# %%
big_movers = f500.loc[['Aviva', 'HP', 'JD.com', 'BHP Billiton'], ['rank', 'previous_rank']]
big_movers
# Out:
#               rank  previous_rank
# company
# Aviva           90            279
# HP             194             48
# JD.com         261            366
# BHP Billiton   350            168

# %%
bottom_companies = f500.loc['National Grid':'AutoNation', ['rank', 'sector', 'country']]
bottom_companies
# Out:
#                                        rank              sector  country
# company
# National Grid                           491              Energy  Britain
# Dollar General                          492           Retailing      USA
# Telecom Italia                          493  Telecommunications    Italy
# Xiamen ITG Holding Group                494         Wholesalers    China
# Xinjiang Guanghui Industry Investment   495         Wholesalers    China
# Teva Pharmaceutical Industries          496         Health Care   Israel
# New China Life Insurance                497          Financials    China
# Wm. Morrison Supermarkets               498  Food & Drug Stores  Britain
# TUI                                     499   Business Services  Germany
# AutoNation                              500           Retailing      USA
